# %% [markdown]
# # Cluster analysis
#
# - compare embeddings on Emotion, Period and PoetTop20
# - save summary tables
# - do a simple top-level tag analysis for the best 3 embeddings

# %%
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, pairwise_distances, silhouette_score

# %% [markdown]
# # Load metadata and embeddings

# %%
embeddings_dir = Path('.')
filtered_embeddings_dir = embeddings_dir / 'filtered_embeddings'
results_dir = embeddings_dir / 'results' / 'cluster_analysis'
projection_dir = results_dir / 'pca_projections'
results_dir.mkdir(parents=True, exist_ok=True)
projection_dir.mkdir(parents=True, exist_ok=True)

data = pd.read_csv(embeddings_dir / 'filtered_poems.csv', engine='python')
embedding_files = sorted(filtered_embeddings_dir.glob('*.npy'))

embeddings = {}
for path in embedding_files:
    arr = np.load(path).astype(np.float64)
    norms = np.linalg.norm(arr, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    embeddings[path.stem] = arr / norms

print(f'Poems: {len(data)}')
print(f'Embeddings: {len(embeddings)}')
print(sorted(embeddings.keys()))
# Out:
# Poems: 2853
# Embeddings: 11
# ['baseline', 'd2v_line_d100_w5_dbow', 'd2v_line_d100_w5_dm', 'd2v_poem_d100_w5_dbow', 'd2v_poem_d100_w5_dm', 'w2v_d100_w5_cbow_avg', 'w2v_d100_w5_cbow_idf', 'w2v_d100_w5_cbow_sif', 'w2v_d100_w5_sg_avg', 'w2v_d100_w5_sg_idf', 'w2v_d100_w5_sg_sif']

# %% [markdown]
# # Prepare tasks

# %%
top_20_poets = data['Poet'].value_counts().head(20).index

tasks = {
    'Emotion': {
        'mask': np.ones(len(data), dtype=bool),
        'labels': data['Emotion'].astype(str).to_numpy(),
        'n_clusters': data['Emotion'].nunique(),
    },
    'Period': {
        'mask': np.ones(len(data), dtype=bool),
        'labels': data['Period'].astype(str).to_numpy(),
        'n_clusters': data['Period'].nunique(),
    },
    'PoetTop20': {
        'mask': data['Poet'].isin(top_20_poets).to_numpy(),
        'labels': data.loc[data['Poet'].isin(top_20_poets), 'Poet'].astype(str).to_numpy(),
        'n_clusters': 20,
    },
}

task_summary_rows = []
for task_name, task in tasks.items():
    labels = pd.Series(task['labels'])
    task_summary_rows.append({
        'task': task_name,
        'n_samples': len(labels),
        'n_clusters': task['n_clusters'],
        'largest_class_size': int(labels.value_counts().max()),
        'smallest_class_size': int(labels.value_counts().min()),
    })

task_summary = pd.DataFrame(task_summary_rows)
task_summary
# Out:
#         task  n_samples  n_clusters  largest_class_size  smallest_class_size
# 0    Emotion       2853           6                 820                  210
# 1     Period       2853           6                 894                   19
# 2  PoetTop20        536          20                  51                   21

# %% [markdown]
# # PCA on data for better clustering
# Preserve 90% of variance and rename embeddings

# %%
EMBEDDING_DICT = {
    'baseline' : 'baseline',
    'w2v_d100_w5_cbow_avg' : 'word_cbow_avg',
    'w2v_d100_w5_cbow_idf' : 'word_cbow_idf',
    'w2v_d100_w5_cbow_sif' : 'word_cbow_sif',
    'w2v_d100_w5_sg_avg' : 'word_sg_avg',
    'w2v_d100_w5_sg_idf' : 'word_sg_idf',
    'w2v_d100_w5_sg_sif' : 'word_sg_sif',
    'd2v_line_d100_w5_dm': 'line_dm',
    'd2v_line_d100_w5_dbow': 'line_dbow',
    'd2v_poem_d100_w5_dm': 'poem_dm',
    'd2v_poem_d100_w5_dbow': 'poem_dbow'
    
}

# %%
pca_embeddings = dict()
for embedding_name, matrix in embeddings.items():
    matrix_reduced = PCA(n_components=0.9, random_state=42, whiten=True).fit_transform(matrix)
    pca_embeddings[EMBEDDING_DICT[embedding_name]] = matrix_reduced
    print( embedding_name, matrix_reduced.shape)
# Out:
# baseline (2853, 80)
# d2v_line_d100_w5_dbow (2853, 74)
# d2v_line_d100_w5_dm (2853, 65)
# d2v_poem_d100_w5_dbow (2853, 78)
# d2v_poem_d100_w5_dm (2853, 70)
# w2v_d100_w5_cbow_avg (2853, 50)
# w2v_d100_w5_cbow_idf (2853, 47)
# w2v_d100_w5_cbow_sif (2853, 55)
# w2v_d100_w5_sg_avg (2853, 61)
# w2v_d100_w5_sg_idf (2853, 61)
# w2v_d100_w5_sg_sif (2853, 65)

# %% [markdown]
# # Helper functions

# %%
TOP_LEVEL_TAGS = [
    'Living',
    'Love',
    'Nature',
    'Activities',
    'Arts & Sciences',
    'Relationships',
    'Social Commentaries',
    'Religion',
    'The Body',
    'Mythology & Folklore',
]

def make_agglomerative(n_clusters):
    try:
        return AgglomerativeClustering(n_clusters=n_clusters, linkage='average', metric='cosine')
    except TypeError:
        return AgglomerativeClustering(n_clusters=n_clusters, linkage='average', affinity='cosine')

def safe_silhouette(matrix, cluster_labels):
    unique = np.unique(cluster_labels)
    if len(unique) < 2 or len(unique) >= len(cluster_labels):
        return np.nan
    return silhouette_score(
        matrix,
        cluster_labels,
        metric='cosine',
        sample_size=min(1500, len(cluster_labels)),
        random_state=42,
    )

def parse_top_level_tags(raw_tags):
    tokens = [token.strip() for token in str(raw_tags).split(',') if token.strip()]
    tags = [tag for tag in TOP_LEVEL_TAGS if tag in tokens]
    if len(tags) == 0:
        tags = ['Other']
    return tags

def mean_within_cluster_jaccard(tag_matrix, cluster_labels):
    total_similarity = 0.0
    total_pairs = 0
    for cluster_id in sorted(np.unique(cluster_labels)):
        row_idx = np.where(cluster_labels == cluster_id)[0]
        if len(row_idx) < 2:
            continue
        distances = pairwise_distances(tag_matrix[row_idx].astype(bool), metric='jaccard')
        similarities = 1.0 - distances[np.triu_indices(len(row_idx), 1)]
        total_similarity += float(similarities.sum())
        total_pairs += len(similarities)
    if total_pairs == 0:
        return np.nan
    return total_similarity / total_pairs

def shuffled_cluster_labels(cluster_labels, rng):
    counts = pd.Series(cluster_labels).value_counts().sort_index()
    shuffled_order = rng.permutation(len(cluster_labels))
    shuffled_labels = np.empty(len(cluster_labels), dtype=int)
    start = 0
    for cluster_id, count in counts.items():
        idx = shuffled_order[start:start + count]
        shuffled_labels[idx] = int(cluster_id)
        start += count
    return shuffled_labels

# %% [markdown]
# # Run clustering

# %%
run_rows = []

for embedding_name, matrix in pca_embeddings.items():
    for task_name, task in tasks.items():
        task_matrix = matrix[task['mask']]
        labels = task['labels']
        n_clusters = task['n_clusters']

        for seed in range(10):
            cluster_labels = KMeans(n_clusters=n_clusters, random_state=seed, n_init=20).fit_predict(task_matrix)
            run_rows.append({
                'embedding': embedding_name,
                'task': task_name,
                'algorithm': 'kmeans',
                'run': seed,
                'n_samples': len(labels),
                'n_clusters': n_clusters,
                'nmi': normalized_mutual_info_score(labels, cluster_labels),
                'ari': adjusted_rand_score(labels, cluster_labels),
                'silhouette': safe_silhouette(task_matrix, cluster_labels),
            })

        cluster_labels = make_agglomerative(n_clusters).fit_predict(task_matrix)
        run_rows.append({
            'embedding': embedding_name,
            'task': task_name,
            'algorithm': 'agglomerative',
            'run': 0,
            'n_samples': len(labels),
            'n_clusters': n_clusters,
            'nmi': normalized_mutual_info_score(labels, cluster_labels),
            'ari': adjusted_rand_score(labels, cluster_labels),
            'silhouette': safe_silhouette(task_matrix, cluster_labels),
        })

run_metrics = pd.DataFrame(run_rows)

summary = (
    run_metrics.groupby(['embedding', 'task', 'algorithm'], as_index=False)
    .agg(
        n_samples=('n_samples', 'first'),
        n_clusters=('n_clusters', 'first'),
        nmi_mean=('nmi', 'mean'),
        nmi_std=('nmi', 'std'),
        ari_mean=('ari', 'mean'),
        ari_std=('ari', 'std'),
        silhouette_mean=('silhouette', 'mean'),
        silhouette_std=('silhouette', 'std'),
    )
    .fillna(0.0)
    .sort_values(['task', 'algorithm', 'nmi_mean'], ascending=[True, True, False])
    .reset_index(drop=True)
)

run_metrics.to_csv(results_dir / 'clustering_run_metrics.csv', index=False)
summary.to_csv(results_dir / 'clustering_summary.csv', index=False)
task_summary.to_csv(results_dir / 'task_summary.csv', index=False)

summary
# Out:
#         embedding       task      algorithm  n_samples  n_clusters  nmi_mean  \
# 0     word_sg_avg    Emotion  agglomerative       2853           6  0.009924
# 1   word_cbow_idf    Emotion  agglomerative       2853           6  0.009875
# 2     word_sg_idf    Emotion  agglomerative       2853           6  0.009373
# 3       line_dbow    Emotion  agglomerative       2853           6  0.008022
# 4   word_cbow_sif    Emotion  agglomerative       2853           6  0.007005
# ..            ...        ...            ...        ...         ...       ...
# 61  word_cbow_sif  PoetTop20         kmeans        536          20  0.249278
# 62    word_sg_idf  PoetTop20         kmeans        536          20  0.248805
# 63    word_sg_avg  PoetTop20         kmeans        536          20  0.247245
# 64       baseline  PoetTop20         kmeans        536          20  0.234709
# 65    word_sg_sif  PoetTop20         kmeans        536          20  0.229140
#
#      nmi_std  ari_mean   ari_std  silhouette_mean  silhouette_std
# 0   0.000000  0.007651  0.000000         0.000699        0.000000
# 1   0.000000  0.007468  0.000000         0.008558        0.000000
# 2   0.000000  0.006832  0.000000        -0.001950        0.000000
# 3   0.000000  0.011545  0.000000         0.012222        0.000000
# 4   0.000000  0.003837  0.000000         0.000155        0.000000
# ..       ...       ...       ...              ...             ...
# 61  0.014933  0.058657  0.011167        -0.029180        0.018856
# 62  0.018001  0.061082  0.012743        -0.048703        0.026962
# 63  0.015294  0.058815  0.013970        -0.066957        0.012153
# 64  0.010467  0.045858  0.007727         0.048196        0.008121
# 65  0.017907  0.045284  0.013903        -0.056444        0.017634
#
# [66 rows x 11 columns]

# %% [markdown]
# # Rank embeddings and save PCA

# %%
kmeans_summary = summary[summary['algorithm'] == 'kmeans']
ranking = kmeans_summary.pivot(index='embedding', columns='task', values='nmi_mean')
ranking = ranking.rank(ascending=False, method='min').mean(axis=1).sort_values()
ranking = ranking.rename('mean_nmi_rank').reset_index()
ranking.columns = ['embedding', 'mean_nmi_rank']

best_embeddings = ranking['embedding'].head(3).tolist()
ranking.to_csv(results_dir / 'embedding_ranking.csv', index=False)

projection_rows = []
for embedding_name in best_embeddings:
    coords = PCA(n_components=2, random_state=42).fit_transform(pca_embeddings[embedding_name])
    projection = data[['Title', 'Poet', 'Emotion', 'Period']].copy()
    projection['pc1'] = coords[:, 0]
    projection['pc2'] = coords[:, 1]
    output_path = projection_dir / f'{embedding_name}_pca_projection.csv'
    projection.to_csv(output_path, index=False)
    projection_rows.append({
        'embedding': embedding_name,
        'projection_csv': str(output_path),
    })

projection_exports = pd.DataFrame(projection_rows)
projection_exports.to_csv(results_dir / 'projection_exports.csv', index=False)

print(best_embeddings)
ranking
# Out:
# ['poem_dbow', 'word_sg_idf', 'word_cbow_idf']
#         embedding  mean_nmi_rank
# 0       poem_dbow       1.333333
# 1     word_sg_idf       3.666667
# 2   word_cbow_idf       4.000000
# 3     word_sg_avg       5.333333
# 4   word_cbow_avg       5.666667
# 5   word_cbow_sif       5.666667
# 6       line_dbow       6.000000
# 7         poem_dm       6.000000
# 8         line_dm       7.666667
# 9        baseline       9.666667
# 10    word_sg_sif      11.000000

# %% [markdown]
# # Simple tag analysis

# %%
parsed_tags = data['Tags'].fillna('').map(parse_top_level_tags)
tag_frame = pd.DataFrame(0, index=data.index, columns=TOP_LEVEL_TAGS + ['Other'], dtype=int)
for idx, tags in parsed_tags.items():
    for tag in tags:
        tag_frame.at[idx, tag] = 1

global_rates = tag_frame.drop(columns=['Other']).mean()
rng = np.random.default_rng(32)

tag_summary_rows = []
tag_enrichment_rows = []

for embedding_name in best_embeddings:
    cluster_labels = KMeans(n_clusters=len(TOP_LEVEL_TAGS), random_state=32, n_init=20).fit_predict(embeddings[embedding_name])

    actual_score = mean_within_cluster_jaccard(tag_frame.to_numpy(), cluster_labels)
    baseline_scores = []
    for _ in range(20):
        baseline_labels = shuffled_cluster_labels(cluster_labels, rng)
        baseline_scores.append(mean_within_cluster_jaccard(tag_frame.to_numpy(), baseline_labels))
    baseline_mean = float(np.mean(baseline_scores))

    tag_summary_rows.append({
        'embedding': embedding_name,
        'analysis_clusters': len(TOP_LEVEL_TAGS),
        'mean_within_cluster_jaccard': actual_score,
        'baseline_mean_jaccard': baseline_mean,
        'jaccard_lift': actual_score / baseline_mean if baseline_mean else np.nan,
    })

    cluster_output = data[['Title', 'Poet', 'Emotion', 'Period']].copy()
    cluster_output['parsed_top_level_tags'] = parsed_tags.map(list)
    cluster_output['cluster_id'] = cluster_labels
    cluster_output.to_csv(results_dir / f'{embedding_name}_tag_clusters.csv', index=False)

    for cluster_id in sorted(np.unique(cluster_labels)):
        mask = cluster_labels == cluster_id
        cluster_rates = tag_frame.loc[mask].drop(columns=['Other']).mean()
        lifts = cluster_rates / global_rates.replace(0, np.nan)
        for tag_name in TOP_LEVEL_TAGS:
            tag_enrichment_rows.append({
                'embedding': embedding_name,
                'cluster_id': int(cluster_id),
                'cluster_size': int(mask.sum()),
                'tag': tag_name,
                'cluster_rate': float(cluster_rates[tag_name]),
                'global_rate': float(global_rates[tag_name]),
                'lift': float(lifts[tag_name]),
            })

tag_jaccard_summary = pd.DataFrame(tag_summary_rows).sort_values('mean_within_cluster_jaccard', ascending=False)
tag_enrichment = pd.DataFrame(tag_enrichment_rows).sort_values(['embedding', 'cluster_id', 'lift'], ascending=[True, True, False])

tag_jaccard_summary.to_csv(results_dir / 'tag_jaccard_summary.csv', index=False)
tag_enrichment.to_csv(results_dir / 'tag_enrichment.csv', index=False)

tag_jaccard_summary
# Out:
#                embedding  analysis_clusters  mean_within_cluster_jaccard  \
# 2     w2v_d100_w5_sg_idf                 10                     0.212724
# 0  d2v_poem_d100_w5_dbow                 10                     0.209892
# 1  d2v_line_d100_w5_dbow                 10                     0.198387
#
#    baseline_mean_jaccard  jaccard_lift
# 2               0.183219      1.161035
# 0               0.183313      1.144995
# 1               0.183478      1.081258

# %%
tag_parsing_inspection = data[['Title', 'Poet', 'Tags']].copy()
tag_parsing_inspection['parsed_top_level_tags'] = parsed_tags.map(list)
tag_parsing_inspection = tag_parsing_inspection.sample(n=min(30, len(tag_parsing_inspection)), random_state=42)
tag_parsing_inspection.to_csv(results_dir / 'tag_parsing_inspection.csv', index=False)

top_cluster_tags = (
    tag_enrichment.groupby(['embedding', 'cluster_id'], sort=True)
    .head(3)
    .reset_index(drop=True)
)

print('Saved files:')
for filename in [
    'clustering_run_metrics.csv',
    'clustering_summary.csv',
    'task_summary.csv',
    'embedding_ranking.csv',
    'projection_exports.csv',
    'tag_jaccard_summary.csv',
    'tag_enrichment.csv',
    'tag_parsing_inspection.csv',
]:
    print(results_dir / filename)

print('\nBest embeddings:')
print(best_embeddings)
print('\nTop enriched tags:')
print(top_cluster_tags[['embedding', 'cluster_id', 'tag', 'lift']].to_string(index=False))

tag_parsing_inspection
# Out:
# Saved files:
# results/cluster_analysis/clustering_run_metrics.csv
# results/cluster_analysis/clustering_summary.csv
# results/cluster_analysis/task_summary.csv
# results/cluster_analysis/embedding_ranking.csv
# results/cluster_analysis/projection_exports.csv
# results/cluster_analysis/tag_jaccard_summary.csv
# results/cluster_analysis/tag_enrichment.csv
# results/cluster_analysis/tag_parsing_inspection.csv
#
# Best embeddings:
# ['d2v_poem_d100_w5_dbow', 'd2v_line_d100_w5_dbow', 'w2v_d100_w5_sg_idf']
#
# Top enriched tags:
#             embedding  cluster_id                  tag     lift
# d2v_line_d100_w5_dbow           0           Activities 1.667897
# d2v_line_d100_w5_dbow           0        Relationships 1.419318
# d2v_line_d100_w5_dbow           0  Social Commentaries 1.302495
# d2v_line_d100_w5_dbow           1 Mythology & Folklore 2.576910
# d2v_line_d100_w5_dbow           1               Nature 1.537942
# d2v_line_d100_w5_dbow           1                 Love 1.075692
# d2v_line_d100_w5_dbow           2                 Love 2.087596
# d2v_line_d100_w5_dbow           2             Religion 1.501937
# d2v_line_d100_w5_dbow           2               Nature 1.126889
# d2v_line_d100_w5_dbow           3               Nature 1.528649
# d2v_line_d100_w5_dbow           3           Activities 1.421962
# d2v_line_d100_w5_dbow           3             The Body 1.269969
# d2v_line_d100_w5_dbow           4             The Body 1.340295
# d2v_line_d100_w5_dbow           4      Arts & Sciences 1.339756
# d2v_line_d100_w5_dbow           4               Living 1.174655
# d2v_line_d100_w5_dbow           5             The Body 1.165771
# d2v_line_d100_w5_dbow           5 Mythology & Folklore 1.147108
# d2v_line_d100_w5_dbow           5               Living 1.139283
# d2v_line_d100_w5_dbow           6             The Body 1.399278
# d2v_line_d100_w5_dbow           6      Arts & Sciences 1.339614
# d2v_line_d100_w5_dbow           6             Religion 1.183977
# d2v_line_d100_w5_dbow           7                 Love 1.938722
# d2v_line_d100_w5_dbow           7             Religion 1.671254
# d2v_line_d100_w5_dbow           7        Relationships 1.260390
# d2v_line_d100_w5_dbow           8  Social Commentaries 1.532363
# d2v_line_d100_w5_dbow           8               Nature 1.380030
# d2v_line_d100_w5_dbow           8 Mythology & Folklore 1.049437
# d2v_line_d100_w5_dbow           9             Religion 4.255487
# d2v_line_d100_w5_dbow           9 Mythology & Folklore 2.785045
# d2v_line_d100_w5_dbow           9                 Love 1.427724
# d2v_poem_d100_w5_dbow           0      Arts & Sciences 1.726344
# d2v_poem_d100_w5_dbow           0  Social Commentaries 1.148773
# d2v_poem_d100_w5_dbow           0           Activities 1.115150
# d2v_poem_d100_w5_dbow           1 Mythology & Folklore 2.243040
# d2v_poem_d100_w5_dbow           1               Nature 1.837359
# d2v_poem_d100_w5_dbow           1             Religion 1.011164
# d2v_poem_d100_w5_dbow           2        Relationships 1.426732
# d2v_poem_d100_w5_dbow           2           Activities 1.313850
# d2v_poem_d100_w5_dbow           2               Living 1.214103
# d2v_poem_d100_w5_dbow           3                 Love 1.631684
# d2v_poem_d100_w5_dbow           3             Religion 1.453738
# d2v_poem_d100_w5_dbow           3 Mythology & Folklore 1.453067
# d2v_poem_d100_w5_dbow           4      Arts & Sciences 1.608450
# d2v_poem_d100_w5_dbow           4               Nature 1.428190
# d2v_poem_d100_w5_dbow           4             The Body 1.416271
# d2v_poem_d100_w5_dbow           5               Nature 1.924883
# d2v_poem_d100_w5_dbow           5 Mythology & Folklore 1.279825
# d2v_poem_d100_w5_dbow           5           Activities 1.197516
# d2v_poem_d100_w5_dbow           6  Social Commentaries 1.882443
# d2v_poem_d100_w5_dbow           6           Activities 1.783490
# d2v_poem_d100_w5_dbow           6        Relationships 1.059351
# d2v_poem_d100_w5_dbow           7             The Body 2.655188
# d2v_poem_d100_w5_dbow           7        Relationships 1.242690
# d2v_poem_d100_w5_dbow           7               Living 1.157511
# d2v_poem_d100_w5_dbow           8  Social Commentaries 1.632943
# d2v_poem_d100_w5_dbow           8           Activities 1.316480
# d2v_poem_d100_w5_dbow           8               Nature 1.216082
# d2v_poem_d100_w5_dbow           9                 Love 2.101704
# d2v_poem_d100_w5_dbow           9             Religion 1.866862
# d2v_poem_d100_w5_dbow           9        Relationships 1.105814
#    w2v_d100_w5_sg_idf           0             Religion 1.657568
#    w2v_d100_w5_sg_idf           0  Social Commentaries 1.261843
#    w2v_d100_w5_sg_idf           0 Mythology & Folklore 1.247533
#    w2v_d100_w5_sg_idf           1           Activities 1.733167
#    w2v_d100_w5_sg_idf           1        Relationships 1.430570
#    w2v_d100_w5_sg_idf           1  Social Commentaries 1.425674
#    w2v_d100_w5_sg_idf           2             The Body 1.965229
#    w2v_d100_w5_sg_idf           2           Activities 1.400460
#    w2v_d100_w5_sg_idf           2        Relationships 1.199704
#    w2v_d100_w5_sg_idf           3                 Love 2.100335
#    w2v_d100_w5_sg_idf           3             Religion 1.820365
#    w2v_d100_w5_sg_idf           3        Relationships 1.099602
#    w2v_d100_w5_sg_idf           4 Mythology & Folklore 2.355544
#    w2v_d100_w5_sg_idf           4               Nature 1.908413
#    w2v_d100_w5_sg_idf           4             Religion 1.237827
#    w2v_d100_w5_sg_idf           5               Nature 2.360591
#    w2v_d100_w5_sg_idf           5 Mythology & Folklore 1.235451
#    w2v_d100_w5_sg_idf           5           Activities 0.923408
#    w2v_d100_w5_sg_idf           6               Nature 1.409301
#    w2v_d100_w5_sg_idf           6             The Body 1.198739
#    w2v_d100_w5_sg_idf           6               Living 1.169589
#    w2v_d100_w5_sg_idf           7                 Love 2.320051
#    w2v_d100_w5_sg_idf           7  Social Commentaries 2.016096
#    w2v_d100_w5_sg_idf           7      Arts & Sciences 1.051991
#    w2v_d100_w5_sg_idf           8  Social Commentaries 1.804360
#    w2v_d100_w5_sg_idf           8           Activities 1.715804
#    w2v_d100_w5_sg_idf           8             The Body 1.070108
#    w2v_d100_w5_sg_idf           9      Arts & Sciences 1.983442
#    w2v_d100_w5_sg_idf           9             The Body 1.485937
#    w2v_d100_w5_sg_idf           9               Living 1.084047
#                                                Title  \
# 2786           from Stanzas in Meditation: Stanza  2
# 1741                                  During the War
# 772                                          Dramedy
# 1743                         Another Insane Devotion
# 387                                  Christmas Carol
# 407                                  Knowlt Hoheimer
# 2288                   A Phonecall from Frank O’Hara
# 1116             Alastor; or, The Spirit of Solitude
# 2442                            Last Words to Miriam
# 2749                                       The Smile
# 2591            from The Princess: As thro' the Land
# 1694                 A Carafe, that is a Blind Glass
# 1001                                     Duncan Gray
# 1361                                    Ellis Island
# 1543                                   Flies on Shit
# 368                                    The late year
# 1829                                     Growing Old
# 678                                 There Is No Word
# 1448                             Sonnet:  Grief Dies
# 450                         from The Unfollowing: 49
# 1210  Sonnet 55: Not marble nor the gilded monuments
# 1461                                Evening Practice
# 1389                The Appalachian Book of the Dead
# 495                                        The Truth
# 1080                      The Arsenal at Springfield
# 1972                                         My Trip
# 1316                                           Faith
# 1963                           The God Called Poetry
# 2091                                 From the Towers
# 1949                                 Author’s Prayer
#
#                             Poet  \
# 2786              Gertrude Stein
# 1741               Philip Levine
# 772                 John Ashbery
# 1743                Gerald Stern
# 387                Sara Teasdale
# 407            Edgar Lee Masters
# 2288                Anne Waldman
# 1116        Percy Bysshe Shelley
# 2442              D. H. Lawrence
# 2749               William Blake
# 2591       Alfred, Lord Tennyson
# 1694              Gertrude Stein
# 1001                Robert Burns
# 1361              Peter Balakian
# 1543              Frank Stanford
# 368                 Marge Piercy
# 1829              Matthew Arnold
# 678                Tony Hoagland
# 1448                Henry Timrod
# 450                 Lyn Hejinian
# 1210         William Shakespeare
# 1461                   D. Nurkse
# 1389              Charles Wright
# 495                     Ross Gay
# 1080  Henry Wadsworth Longfellow
# 1972               Donald Revell
# 1316            Louis Untermeyer
# 1963               Robert Graves
# 2091              Heather McHugh
# 1949               Ilya Kaminsky
#
#                                                    Tags  \
# 2786  Relationships,Arts & Sciences,Language & Lingu...
# 1741  Living,Sorrow & Grieving,Social Commentaries,W...
# 772                                 Living,Life Choices
# 1743                Love,Relationships,Men & Women,Pets
# 387                                           Christmas
# 407   Social Commentaries,Crime & Punishment,Town & ...
# 2288  Living,Death,Relationships,Friends & Enemies,A...
# 1116  Living,Death,Sorrow & Grieving,The Mind,Activi...
# 2442  Living,Separation & Divorce,Love,Break-ups & V...
# 2749  Living,Love,Infatuation & Crushes,Realistic & ...
# 2591  Living,Death,Marriage & Companionship,Parentho...
# 1694             Arts & Sciences,Language & Linguistics
# 1001  Love,Realistic & Complicated,Relationships,Men...
# 1361  Social Commentaries,History & Politics,Indepen...
# 1543  Nature,Animals,Arts & Sciences,Poetry & Poets,...
# 368   Living,Death,Growing Old,Time & Brevity,Nature...
# 1829                                 Living,Growing Old
# 678   Relationships,Friends & Enemies,Arts & Science...
# 1448  Living,Sorrow & Grieving,Religion,Faith & Doub...
# 450                                     Living,The Mind
# 1210  Living,Death,Time & Brevity,Love,Classic Love,...
# 1461  Activities,Sports & Outdoor Activities,Relatio...
# 1389  Living,Death,The Body,Nature,Fall,Religion,God...
# 495   Activities,Jobs & Working,Social Commentaries,...
# 1080  Arts & Sciences,Music,Social Commentaries,War ...
# 1972  Arts & Sciences,Poetry & Poets,Reading & Books...
# 1316                             Religion,Faith & Doubt
# 1963  Life Choices,Arts & Sciences,Poetry & Poets,So...
# 2091                  Living,Arts & Sciences,Philosophy
# 1949  Living,Death,The Body,Nature,Arts & Sciences,P...
#
#                                   parsed_top_level_tags
# 2786                   [Arts & Sciences, Relationships]
# 1741                      [Living, Social Commentaries]
# 772                                            [Living]
# 1743                              [Love, Relationships]
# 387                                             [Other]
# 407         [Social Commentaries, Mythology & Folklore]
# 2288           [Living, Arts & Sciences, Relationships]
# 1116      [Living, Nature, Activities, Arts & Sciences]
# 2442                      [Living, Love, Relationships]
# 2749                      [Living, Love, Relationships]
# 2591                                           [Living]
# 1694                                  [Arts & Sciences]
# 1001                              [Love, Relationships]
# 1361                              [Social Commentaries]
# 1543     [Nature, Arts & Sciences, Social Commentaries]
# 368                          [Living, Nature, Religion]
# 1829                                           [Living]
# 678                    [Arts & Sciences, Relationships]
# 1448                                 [Living, Religion]
# 450                                            [Living]
# 1210  [Living, Love, Relationships, Social Commentar...
# 1461                        [Activities, Relationships]
# 1389               [Living, Nature, Religion, The Body]
# 495                   [Activities, Social Commentaries]
# 1080  [Arts & Sciences, Social Commentaries, Mytholo...
# 1972             [Arts & Sciences, Social Commentaries]
# 1316                                         [Religion]
# 1963             [Arts & Sciences, Social Commentaries]
# 2091                          [Living, Arts & Sciences]
# 1949        [Living, Nature, Arts & Sciences, The Body]

# %% [markdown]
# # Plots

# %%
from matplotlib import pyplot as plt

figures_dir = results_dir / 'figures'
figures_dir.mkdir(parents=True, exist_ok=True)

kmeans_summary = summary[summary['algorithm'] == 'kmeans']

# %%
for task_name in ['Emotion', 'Period', 'PoetTop20']:
    task_df = kmeans_summary[kmeans_summary['task'] == task_name].copy()

    nmi_df = task_df.sort_values('nmi_mean', ascending=False)
    plt.figure(figsize=(8, 4))
    plt.bar(nmi_df['embedding'], nmi_df['nmi_mean'])
    plt.xlabel('Embedding')
    plt.ylabel('Mean NMI')
    plt.title(f'KMeans clustering quality by embedding ({task_name})')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(figures_dir / f'fig_{task_name.lower()}_nmi.png', dpi=300)
    plt.show()

    ari_df = task_df.sort_values('ari_mean', ascending=False)
    plt.figure(figsize=(8, 4))
    plt.bar(ari_df['embedding'], ari_df['ari_mean'])
    plt.xlabel('Embedding')
    plt.ylabel('Mean ARI')
    plt.title(f'KMeans clustering quality by embedding ({task_name})')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(figures_dir / f'fig_{task_name.lower()}_ari.png', dpi=300)
    plt.show()

    silhouette_df = task_df.sort_values('silhouette_mean', ascending=False)
    plt.figure(figsize=(8, 4))
    plt.bar(silhouette_df['embedding'], silhouette_df['silhouette_mean'])
    plt.xlabel('Embedding')
    plt.ylabel('Mean silhouette')
    plt.title(f'KMeans clustering quality by embedding ({task_name})')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(figures_dir / f'fig_{task_name.lower()}_silhouette.png', dpi=300)
    plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.bar(ranking['embedding'], ranking['mean_nmi_rank'])
plt.xlabel('Embedding')
plt.ylabel('Mean rank (lower is better)')
plt.title('Overall embedding rank across clustering tasks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(figures_dir / 'fig_embedding_rank.png', dpi=300)
plt.show()

# %%
x = np.arange(len(tag_jaccard_summary))
width = 0.35

plt.figure(figsize=(8, 4))
plt.bar(x - width / 2, tag_jaccard_summary['mean_within_cluster_jaccard'], width, label='Clusters')
plt.bar(x + width / 2, tag_jaccard_summary['baseline_mean_jaccard'], width, label='Shuffled baseline')
plt.xticks(x, tag_jaccard_summary['embedding'], rotation=45, ha='right')
plt.ylabel('Mean Jaccard overlap')
plt.title('Top-level tag consistency inside clusters')
plt.legend()
plt.tight_layout()
plt.savefig(figures_dir / 'fig_tag_jaccard.png', dpi=300)
plt.show()

print('Saved figures:')
for filename in [
    'fig_emotion_nmi.png',
    'fig_period_nmi.png',
    'fig_poettop20_nmi.png',
    'fig_emotion_ari.png',
    'fig_period_ari.png',
    'fig_poettop20_ari.png',
    'fig_emotion_silhouette.png',
    'fig_period_silhouette.png',
    'fig_poettop20_silhouette.png',
    'fig_embedding_rank.png',
    'fig_tag_jaccard.png',
]:
    print(figures_dir / filename)
# Out:
# Saved figures:
# results/cluster_analysis/figures/fig_emotion_nmi.png
# results/cluster_analysis/figures/fig_period_nmi.png
# results/cluster_analysis/figures/fig_poettop20_nmi.png
# results/cluster_analysis/figures/fig_embedding_rank.png
# results/cluster_analysis/figures/fig_tag_jaccard.png

# %%
for embedding_name in best_embeddings:
    projection_path = projection_dir / f'{embedding_name}_pca_projection.csv'
    projection_df = pd.read_csv(projection_path)

    for label_column in ['Emotion', 'Period']:
        plt.figure(figsize=(8, 6))
        for label, group in projection_df.groupby(label_column):
            plt.scatter(group['pc1'], group['pc2'], s=10, alpha=0.7, label=label)
        plt.xlabel('PC1')
        plt.ylabel('PC2')
        plt.title(f'{embedding_name} PCA colored by {label_column}')
        plt.legend(markerscale=2, bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        plt.savefig(figures_dir / f'fig_{embedding_name}_pca_{label_column.lower()}.png', dpi=300)
        plt.show()

print('Saved PCA figures:')
for embedding_name in best_embeddings:
    print(figures_dir / f'fig_{embedding_name}_pca_emotion.png')
    print(figures_dir / f'fig_{embedding_name}_pca_period.png')
# Out:
# Saved PCA figures:
# results/cluster_analysis/figures/fig_poem_dbow_pca_emotion.png
# results/cluster_analysis/figures/fig_poem_dbow_pca_period.png
# results/cluster_analysis/figures/fig_word_sg_idf_pca_emotion.png
# results/cluster_analysis/figures/fig_word_sg_idf_pca_period.png
# results/cluster_analysis/figures/fig_word_cbow_idf_pca_emotion.png
# results/cluster_analysis/figures/fig_word_cbow_idf_pca_period.png
