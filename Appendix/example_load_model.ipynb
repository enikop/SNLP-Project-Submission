# %% [markdown]
# # Load word2vec

# %%
from gensim.models import Word2Vec

model_cbow = Word2Vec.load("models/w2v_d100_w5_cbow.model")

# Access word vector
vector = model_cbow.wv['<linesep>']
vector
# Out:
# array([ 0.79193664, -0.2652275 ,  0.11313582,  0.26923612, -0.6989977 ,
#         0.17676544, -0.26643905,  0.90798724,  1.0684769 ,  0.6270054 ,
#         0.01111345, -0.02853385, -0.26036388,  0.00506914, -0.3012504 ,
#         0.05838605, -0.102675  , -0.27646345, -0.44260275,  0.7455506 ,
#        -0.14518067,  0.14869925,  0.5156463 , -0.02931942,  0.22673811,
#         0.711647  ,  0.39210144,  0.26023543,  0.39366746,  0.81545085,
#        -0.65782875, -0.11681689,  0.96478385, -0.24397793,  0.45863196,
#        -0.12064514,  0.24546048,  1.2585561 ,  0.62382716,  0.92784363,
#        -0.76525   , -0.08027536,  0.75625217, -0.00211905,  0.705887  ,
#         0.06009356,  0.71854466, -0.04080578,  0.746656  ,  0.4575678 ,
#        -0.38847148,  0.47263643, -0.30125695, -0.13242067, -0.14599189,
#        -0.5370194 , -0.04950268, -0.15378334,  0.16634205,  0.20749491,
#         0.23267274, -0.07636297, -0.32228184, -0.5353653 ,  0.7190679 ,
# ...

# %% [markdown]
# # Load doc2vec

# %%
from gensim.models import Doc2Vec

model = Doc2Vec.load("models/d2v_line_d100_w5_dm.model")

# Access document vector
vector = model.dv['0_0']  # example: poem 0, line 0
vector
# Out:
# array([-0.07845912,  0.04901239, -0.02291892, -0.07963059,  0.04808468,
#        -0.16011882,  0.11228476,  0.1805613 , -0.01889372, -0.03602533,
#         0.08532092, -0.13191478,  0.00879266,  0.04344318, -0.05326879,
#        -0.04036669,  0.05222522, -0.12976882, -0.01034594, -0.04975586,
#        -0.0742818 , -0.02549702,  0.14862813, -0.01894436,  0.11173336,
#        -0.06460498, -0.04759203, -0.07379055,  0.00108927,  0.10634845,
#         0.0532102 ,  0.02902812,  0.00487383, -0.09721699, -0.0425093 ,
#         0.14108486, -0.03244543, -0.10323005, -0.09926467, -0.21814878,
#        -0.04712574, -0.19819494,  0.07592496,  0.07251479, -0.04365745,
#        -0.04649725, -0.05604664, -0.02837079,  0.12989253,  0.0583945 ,
#        -0.18245259, -0.02470758, -0.01400355,  0.04553512,  0.02858848,
#        -0.02152024,  0.09126651, -0.07219545, -0.0747655 ,  0.09513614,
#         0.17480919, -0.07647151,  0.01763857,  0.1076565 ,  0.05445058,
# ...
